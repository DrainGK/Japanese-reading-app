# %%
import json
from pathlib import Path
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = Path("../src/data/passages.json")

# %%
df = pd.read_json(data_path)
df
# Out:
#        id title          author difficulty  char_count  kanji_count  \
# 0       0   三四郎            夏目漱石     normal         801          171
# 1       1  おはなし            夏目漱石     normal         816          179
# 2       2    草枕            夏目漱石     normal         811          144
# 3       3    草枕            夏目漱石     normal         838          184
# 4       4   三四郎            夏目漱石     normal         821          180
# ...   ...   ...             ...        ...         ...          ...
# 1995  1jf   春の潮           伊藤左千夫       easy         844          131
# 1996  1jg  透明人間  ウェルズハーバート・ジョージ       easy         806           92
# 1997  1jh  透明人間  ウェルズハーバート・ジョージ       easy         817          110
# 1998  1ji  透明人間  ウェルズハーバート・ジョージ       easy         847          101
# 1999  1jj  透明人間  ウェルズハーバート・ジョージ       easy         819          100
#
#       kanji_ratio  unique_kanji_count  unique_kanji_ratio  sentence_count  \
# 0          0.2135                  95              0.5556              25
# 1          0.2194                  94              0.5251              17
# 2          0.1776                  80              0.5556              20
# 3          0.2196                  86              0.4674              23
# 4          0.2192                 101              0.5611              27
# ...           ...                 ...                 ...             ...
# 1995       0.1552                  62              0.4733              18
# 1996       0.1141                  44              0.4783              22
# 1997       0.1346                  60              0.5455              24
# 1998       0.1192                  38              0.3762              23
# 1999       0.1221                  39              0.3900              17
#
#       avg_sentence_len                                               text
# 0                32.04  しかしなんといったら破れるか、まるで分別が出なかった。\n\n小説などにある甘い言葉は使いた...
# 1                48.00  当人が文学者になれというたのはよほどの自信があったからでしょう。\n\n私はそれでふっつりや...
# 2                40.55  ただ机の上へ、こう開けて、開いた所をいい加減に読んでるんです」\n「それで面白いんですか」\...
# 3                36.43  そんなに年をとっても、やっぱり、惚れたの、腫れたの、にきびが出来たのってえ事が面白いんですか...
# 4                30.41  三四郎はまたそっと自分の席に帰った。\n\n乗合いはだいぶいる。\n\nけれども三四郎の挙動...
# ...                ...                                                ...
# 1995             46.89  わたしもう癪に障っちゃったから」\n「困ったなあ、だれが一番悪くあたるかい。\n\nおつねも...
# 1996             36.64  いいだろう――」\n 男は、とりつくろったようすで、重々しくこたえた。\n\n「では、テッデ...
# 1997             34.04  巡査は、苦心のすえに相手の首をしめあげた。\n\nもちろん、見えない首をしめあげるのだから、...
# 1998             36.83  トーマスが、見しらぬ船員にかれのことをしゃべりそうになると、ぐいぐいとトーマスの耳をつまみあ...
# 1999             48.18  ただおれはふとしたことで体がすきとおってしまい、人の目に見えなくなってしまったんだ。\n\n...
#
# [2000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  2000 non-null   str
#  1   title               2000 non-null   str
#  2   author              2000 non-null   str
#  3   difficulty          2000 non-null   str
#  4   char_count          2000 non-null   int64
#  5   kanji_count         2000 non-null   int64
#  6   kanji_ratio         2000 non-null   float64
#  7   unique_kanji_count  2000 non-null   int64
#  8   unique_kanji_ratio  2000 non-null   float64
#  9   sentence_count      2000 non-null   int64
#  10  avg_sentence_len    2000 non-null   float64
#  11  text                2000 non-null   str
# dtypes: float64(3), int64(4), str(5)
# memory usage: 187.6 KB

# %%
df.drop(['difficulty'], axis=1)
# Out:
#        id title          author  char_count  kanji_count  kanji_ratio  \
# 0       0   三四郎            夏目漱石         801          171       0.2135
# 1       1  おはなし            夏目漱石         816          179       0.2194
# 2       2    草枕            夏目漱石         811          144       0.1776
# 3       3    草枕            夏目漱石         838          184       0.2196
# 4       4   三四郎            夏目漱石         821          180       0.2192
# ...   ...   ...             ...         ...          ...          ...
# 1995  1jf   春の潮           伊藤左千夫         844          131       0.1552
# 1996  1jg  透明人間  ウェルズハーバート・ジョージ         806           92       0.1141
# 1997  1jh  透明人間  ウェルズハーバート・ジョージ         817          110       0.1346
# 1998  1ji  透明人間  ウェルズハーバート・ジョージ         847          101       0.1192
# 1999  1jj  透明人間  ウェルズハーバート・ジョージ         819          100       0.1221
#
#       unique_kanji_count  unique_kanji_ratio  sentence_count  \
# 0                     95              0.5556              25
# 1                     94              0.5251              17
# 2                     80              0.5556              20
# 3                     86              0.4674              23
# 4                    101              0.5611              27
# ...                  ...                 ...             ...
# 1995                  62              0.4733              18
# 1996                  44              0.4783              22
# 1997                  60              0.5455              24
# 1998                  38              0.3762              23
# 1999                  39              0.3900              17
#
#       avg_sentence_len                                               text
# 0                32.04  しかしなんといったら破れるか、まるで分別が出なかった。\n\n小説などにある甘い言葉は使いた...
# 1                48.00  当人が文学者になれというたのはよほどの自信があったからでしょう。\n\n私はそれでふっつりや...
# 2                40.55  ただ机の上へ、こう開けて、開いた所をいい加減に読んでるんです」\n「それで面白いんですか」\...
# 3                36.43  そんなに年をとっても、やっぱり、惚れたの、腫れたの、にきびが出来たのってえ事が面白いんですか...
# 4                30.41  三四郎はまたそっと自分の席に帰った。\n\n乗合いはだいぶいる。\n\nけれども三四郎の挙動...
# ...                ...                                                ...
# 1995             46.89  わたしもう癪に障っちゃったから」\n「困ったなあ、だれが一番悪くあたるかい。\n\nおつねも...
# 1996             36.64  いいだろう――」\n 男は、とりつくろったようすで、重々しくこたえた。\n\n「では、テッデ...
# 1997             34.04  巡査は、苦心のすえに相手の首をしめあげた。\n\nもちろん、見えない首をしめあげるのだから、...
# 1998             36.83  トーマスが、見しらぬ船員にかれのことをしゃべりそうになると、ぐいぐいとトーマスの耳をつまみあ...
# 1999             48.18  ただおれはふとしたことで体がすきとおってしまい、人の目に見えなくなってしまったんだ。\n\n...
#
# [2000 rows x 11 columns]

# %%
features = []

for text in df['text']:
    text_length = len(text)
    seen = set()
    unique_kanjis = []
    kanjis = "".join(re.findall(r"[一-龯々]", text))
    for char in kanjis:
        if char not in seen:
            seen.add(char)
            unique_kanjis.append(char)
    kanjis_count = len(kanjis)
    unique_kanjis_count= len(unique_kanjis)
    kanji_ratio = kanjis_count/text_length*100
    unique_kanji_ratio = (unique_kanjis_count / kanjis_count * 100) if kanjis_count > 0 else 0

    features.append({
        "text_length": text_length,
        "kanjis_count": kanjis_count,
        "unique_kanjis_count": unique_kanjis_count,
        "kanji_ratio": kanji_ratio,
        "unique_kanji_ratio": unique_kanji_ratio,
    })

features_df = pd.DataFrame(features)

df = pd.concat([df.reset_index(drop=True), features_df], axis = 1)

# %%
print(df[["text_length", "kanjis_count", "kanji_ratio", "unique_kanji_ratio"]].describe())
# Out:
#        text_length  kanjis_count  kanji_ratio  kanji_ratio  \
# count  2000.000000   2000.000000  2000.000000  2000.000000
# mean    807.678500    173.244500     0.214814    21.481406
# std      75.422095     49.803121     0.059370     5.937048
# min     295.000000     14.000000     0.047500     4.745763
# 25%     807.000000    137.000000     0.177425    17.743665
# 50%     829.000000    176.000000     0.216800    21.678762
# 75%     841.000000    198.000000     0.239100    23.910483
# max     996.000000    357.000000     0.518600    51.858108
#
#        unique_kanji_ratio  unique_kanji_ratio
# count         2000.000000         2000.000000
# mean             0.567287           56.728744
# std              0.081160            8.116034
# min              0.241900           24.187726
# 25%              0.516775           51.675056
# 50%              0.567250           56.720782
# 75%              0.618075           61.808921
# max              0.908000           90.804598

# %%
df["kanji_ratio"].hist(bins=30)
plt.title("Distribution of Kanjis Ratio")
plt.xlabel("Kanjis Ratio (%)")
plt.ylabel("Number or Texts")
plt.show()

# %%
plt.scatter(df["text_length"], df["kanji_ratio"])
plt.title("Text Length vs Kanji Ratio")
plt.xlabel("Text Length")
plt.ylabel("Kanji Ratio (%)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.scatter(df["text_length"], df["kanji_ratio"])
#       2 plt.title("Text Length vs Kanji Ratio")
#       3 plt.xlabel("Text Length")
#
# File ~\anaconda3\envs\jltest\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jltest\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File ~\anaconda3\envs\jltest\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jltest\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\jltest\Lib\site-packages\matplotlib\axes\_axes.py:4936, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4934 y = np.ma.ravel(y)
#    4935 if x.size != y.size:
# -> 4936     raise ValueError("x and y must be the same size")
#    4938 if s is None:
#    4939     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4940          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
plt.scatter(df["kanjis_count"], df["unique_kanjis_count"])
plt.title("Total kanjis vs unique kanjis")
plt.xlabel("Kanjis count")
plt.ylabel("Unique Kanjis count")
plt.show()

# %%
df["difficulty_score"] = (
    df["kanji_ratio"] * 0.4 +
    df["unique_kanji_ratio"] * 0.6
)
df[["author","text", "difficulty_score"]].sort_values(by="difficulty_score", ascending=False).head()
df[["author","text", "difficulty_score"]].sort_values(by="difficulty_score", ascending=True).head()

# %%
def difficulty_label(score):
    if score < 35:
        return "easy"
    elif score < 55:
        return "medium"
    else:
        return "hard"
df["difficulty_label"] = df["difficulty_score"].apply(difficulty_label)

df["difficulty_label"].value_counts()

# %%
df["difficulty_label"].value_counts().plot(kind="bar")

# %%
df["author"]

# %%
author_difficulty = df.groupby("author")["difficulty_score"].mean().sort_values(ascending=False)
print(author_difficulty)

# %%
import matplotlib as mpl

mpl.rcParams["font.family"] = "Yu Gothic"

author_difficulty.plot(kind="bar", figsize=(12,6))
plt.title("Average Difficulty Score by author")
plt.xlabel("Author")
plt.ylabel("Average Diffiulty Score")
plt.show()
